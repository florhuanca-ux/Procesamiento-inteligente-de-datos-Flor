# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt 
# %matplotlib inline

#Librerias para operaciones de regresion Lineal
from sklearn import linear_model 
from sklearn. metrics import mean_squared_error, r2_score

# %%
data = pd.read_csv("./CopierSalesofAmerica.csv")

# %%
#Determinen la cantidad de filas y columnas del archivo
data.shape

# %%
#Mostrar la tabla
data.head()

# %%
#Seleccionar los datos para determinar el coeficiente de correlacion
X_train = np.array(data['llamadas']).reshape(-1,1)
Y_train = np.array(data['ventas'])

# %%
#calcular la el formula de regresion lineal
r = linear_model.LinearRegression()
#Entrenando el modelo con los datos
r.fit(X_train, Y_train)

#Obtener las predicciones
#valores para y
Y_pred = r.predict(X_train)

print('Coeficiente de correlacion: ', r.coef_)
print('Interseccion: ', r.intercept_)
print('Error cuadratico de la media: ', mean_squared_error(Y_train, Y_pred))
print('Varianza: ', r2_score(Y_train, Y_pred))
# Out:
# Coeficiente de correlacion:  [1.18421053]
# Interseccion:  18.94736842105263
# Error cuadratico de la media:  78.42105263157899
# Varianza:  0.5761024182076812

# %%
#Realizar la grafica de dispersion y la pendiente
x = X_train.ravel()
plt.figure(figsize=(8,5))
plt.scatter(x_plot, y, color='steelblue', s=80, label='Datos reales')
plt.plot(x_plot, y_pred, color='red', linewidth=3, label='Regresión lineal')
plt.xlabel('No. de llamadas')
plt.ylabel('Copiadoras vendidas')
plt.title('Copier Sales of America')
plt.legend()
plt.grid(True, linestyle='--', alpha=0.5)
plt.show() # Para mostrar la gráfica final
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 4
#       2 x = X_train.ravel()
#       3 plt.figure(figsize=(8,5))
# ----> 4 plt.scatter(x_plot, y, color='steelblue', s=80, label='Datos reales')
#       5 plt.plot(x_plot, y_pred, color='red', linewidth=3, label='Regresión lineal')
#       6 plt.xlabel('No. de llamadas')
#
# NameError: name 'x_plot' is not defined

# %%
x = X_train.ravel()
plt.figure(figsize=(8,5))
plt.scatter(x, Y_train, color='steelblue', s=80, label='Datos reales')
plt.plot(x, Y_pred, color='red', linewidth=3, label='Regresión lineal')
plt.xlabel('No. de llamadas')
plt.ylabel('Copiadoras vendidas')
plt.title('Copier Sales of America')
plt.legend()
plt.grid(True, linestyle='--', alpha=0.5)
plt.show() # Para mostrar la gráfica final
