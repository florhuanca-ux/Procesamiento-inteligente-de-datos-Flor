# %%
import pandas as pd 
import matplotlib.pyplot as plt 
import seaborn as sns
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.datasets import load_diabetes
from sklearn.model_selection import train_test_split

# %%
diabetes_data = load_diabetes()
df_diabetes = pd.DataFrame(diabetes_data.data, columns=diabetes_data.feature_names)
df_diabetes['target'] = diabetes_data.target

# %%
x = df_diabetes['bmi'].values.reshape(-1, 1)
y = df_diabetes['target'].values.reshape(-1, 1)

# %%
X_train, X_test, Y_train, Y_test = train_test_split(x, y, test_size=20, shuffle=False)

# %%
regressor = LinearRegression()
regressor.fit(X_train, Y_train)
# Out:
# LinearRegression()

# %%
y_pred = regressor.predict(X_test)

# %%
print("Mean squared error: %.2f" % mean_squared_error(Y_test, y_pred))
print("Coefficient of determination: %.2f" % r2_score(Y_test, y_pred))
# Out:
# Mean squared error: 2548.07
# Coefficient of determination: 0.47

# %%
sns.set_theme()
fig, ax = plt.subplots(1, 2, figsize=(12, 6), sharey=True)
ax[0].scatter(X_train, Y_train)
ax[0].plot(X_train, regressor.predict(X_train), color='darkorange', linewidth=3)
ax[0].set_title('Train set')
ax[0].set_xlabel('Feature')
ax[0].set_ylabel('Target')
ax[1].scatter(X_test, Y_test)
ax[1].plot(X_test, y_pred, color='darkorange', linewidth=3)
ax[1].set_title('Test set')
ax[1].set_xlabel('Feature')
ax[1].set_ylabel('Target')
plt.suptitle('Linear Regression')
plt.show()

# %% [markdown]
# # Conclusion
#  ### En este ejercicio aplicamos un modelo de Regresión Lineal para predecir la progresión de la diabetes en pacientes basándonos únicamente en su Índice de Masa Corporal (IMC).El procedimiento realizado fue:
#  Preparación de datos: Se cargó el dataset diabetes y se separaron las variables: la variable independiente (x) fue el IMC y la variable dependiente (y) fue la progresión de la enfermedad.
#
#   División del conjunto: Se dividieron los datos en dos grupos: un set de entrenamiento para enseñar al modelo y un set de prueba (los últimos 20 datos) para validarlo.
#
#  Entrenamiento: Se entrenó el modelo lineal utilizando los datos de entrenamiento para encontrar la línea de mejor ajuste.Evaluación: Se probó el modelo con el set de prueba, obteniendo un Mean Squared Error de 2548.07 y un Coeficiente de Determinación (R^2) de 0.47.
#
#  El resultado de R^2 = 0.47 indica que el IMC por sí solo explica aproximadamente el 47% de la variación en la progresión de la enfermedad. Aunque existe una relación positiva el modelo podría mejorar si se incluyeran más variables médicas además del peso.
